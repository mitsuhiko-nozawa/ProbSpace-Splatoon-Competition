# %% [markdown]
# チームの情報を追加

# %%
import sys
sys.path.append('../')
import pandas as pd
import numpy as np
import sklearn
from Functions import prepro

# %%
train_df = pd.read_csv("../../data/Processed/train_buki.csv", index_col='id')
test_df = pd.read_csv("../../data/Processed/test_buki.csv", index_col="id")
print(train_df.shape)
print(test_df.shape)
# Out:
# (66125, 79)
# (28340, 78)

# %%
train_df.head()
# Out:
#                        period game-ver lobby-mode     lobby      mode  \
# id
# 1   2019-10-15T20:00:00+00:00    5.0.1    regular  standard  nawabari
# 2   2019-12-14T04:00:00+00:00    5.0.1    regular  standard  nawabari
# 3   2019-12-25T14:00:00+00:00    5.0.1      gachi  standard      hoko
# 4   2019-11-11T14:00:00+00:00    5.0.1    regular  standard  nawabari
# 5   2019-12-14T06:00:00+00:00    5.0.1      gachi  standard      hoko
#
#       stage            A1-weapon A1-rank  A1-level           A2-weapon  ...  \
# id                                                                      ...
# 1   sumeshi      sshooter_becchu     NaN       139     soytuber_custom  ...
# 2   arowana  parashelter_sorella     NaN       198          jetsweeper  ...
# 3       ama               nzap89      a-       114    quadhopper_black  ...
# 4    engawa          bamboo14mk1     NaN       336  splatroller_becchu  ...
# 5   chozame               bold_7       x       299          hissen_hue  ...
#
#    subweapon-B3           special-B3   mainweapon-B3           reskin-B3  \
# id
# 1    splashbomb              presser    splatcharger        splatcharger
# 2    jumpbeacon               bubble  campingshelter      campingshelter
# 3    splashbomb             nicedama           prime        prime_becchu
# 4    kyubanbomb  curlingbomb_pitcher   promodeler_mg       promodeler_mg
# 5    splashbomb    quickbomb_pitcher   bucketslosher  bucketslosher_soda
#
#     category1-B4 category2-B4 subweapon-B4          special-B4 mainweapon-B4  \
# id
# 1        shooter      shooter    quickbomb  kyubanbomb_pitcher         sharp
# 2        shooter     maneuver      torpedo            chakuchi      sputtery
# 3        shooter     maneuver   splashbomb          amefurashi   dualsweeper
# 4        shooter      blaster    robotbomb             jetpack    hotblaster
# 5        shooter      shooter   splashbomb               armor        wakaba
#
#              reskin-B4
# id
# 1            sharp_neo
# 2       sputtery_clear
# 3   dualsweeper_custom
# 4    hotblaster_custom
# 5               wakaba
#
# [5 rows x 79 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66125 entries, 1 to 66125
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   period         66125 non-null  object
#  1   game-ver       66125 non-null  object
#  2   lobby-mode     66125 non-null  object
#  3   lobby          66125 non-null  object
#  4   mode           66125 non-null  object
#  5   stage          66125 non-null  object
#  6   A1-weapon      66125 non-null  object
#  7   A1-rank        51681 non-null  object
#  8   A1-level       66125 non-null  int64
#  9   A2-weapon      66125 non-null  object
#  10  A2-rank        51681 non-null  object
#  11  A2-level       66125 non-null  float64
#  12  A3-weapon      66125 non-null  object
#  13  A3-rank        51681 non-null  object
#  14  A3-level       66125 non-null  float64
#  15  A4-weapon      66074 non-null  object
#  16  A4-rank        51638 non-null  object
#  17  A4-level       66074 non-null  float64
#  18  B1-weapon      66125 non-null  object
#  19  B1-rank        51681 non-null  object
#  20  B1-level       66125 non-null  int64
#  21  B2-weapon      66125 non-null  object
#  22  B2-rank        51681 non-null  object
#  23  B2-level       66125 non-null  float64
#  24  B3-weapon      66124 non-null  object
#  25  B3-rank        51681 non-null  object
#  26  B3-level       66124 non-null  float64
#  27  B4-weapon      66058 non-null  object
#  28  B4-rank        51624 non-null  object
#  29  B4-level       66058 non-null  float64
#  30  y              66125 non-null  int64
#  31  category1-A1   66125 non-null  object
#  32  category2-A1   66125 non-null  object
#  33  subweapon-A1   66125 non-null  object
#  34  special-A1     66125 non-null  object
#  35  mainweapon-A1  66125 non-null  object
#  36  reskin-A1      66125 non-null  object
#  37  category1-A2   66125 non-null  object
#  38  category2-A2   66125 non-null  object
#  39  subweapon-A2   66125 non-null  object
#  40  special-A2     66125 non-null  object
#  41  mainweapon-A2  66125 non-null  object
#  42  reskin-A2      66125 non-null  object
#  43  category1-A3   66125 non-null  object
#  44  category2-A3   66125 non-null  object
#  45  subweapon-A3   66125 non-null  object
#  46  special-A3     66125 non-null  object
#  47  mainweapon-A3  66125 non-null  object
#  48  reskin-A3      66125 non-null  object
#  49  category1-A4   66074 non-null  object
#  50  category2-A4   66074 non-null  object
#  51  subweapon-A4   66074 non-null  object
#  52  special-A4     66074 non-null  object
#  53  mainweapon-A4  66074 non-null  object
#  54  reskin-A4      66074 non-null  object
#  55  category1-B1   66125 non-null  object
#  56  category2-B1   66125 non-null  object
#  57  subweapon-B1   66125 non-null  object
#  58  special-B1     66125 non-null  object
#  59  mainweapon-B1  66125 non-null  object
#  60  reskin-B1      66125 non-null  object
#  61  category1-B2   66125 non-null  object
#  62  category2-B2   66125 non-null  object
#  63  subweapon-B2   66125 non-null  object
#  64  special-B2     66125 non-null  object
#  65  mainweapon-B2  66125 non-null  object
#  66  reskin-B2      66125 non-null  object
#  67  category1-B3   66124 non-null  object
#  68  category2-B3   66124 non-null  object
#  69  subweapon-B3   66124 non-null  object
#  70  special-B3     66124 non-null  object
#  71  mainweapon-B3  66124 non-null  object
#  72  reskin-B3      66124 non-null  object
#  73  category1-B4   66058 non-null  object
#  74  category2-B4   66058 non-null  object
#  75  subweapon-B4   66058 non-null  object
#  76  special-B4     66058 non-null  object
#  77  mainweapon-B4  66058 non-null  object
#  78  reskin-B4      66058 non-null  object
# dtypes: float64(6), int64(3), object(70)
# memory usage: 40.4+ MB

# %% [markdown]
# ### 武器の情報を個人ごとからチームごとに変える
# category1, 2を落とす、
#
# 他のカテゴリをチームごとにする
#
# reskinそのまま

# %%
suffixes = ["-A1", "-A2", "-A3", "-A4", "-B1", "-B2", "-B3", "-B4"]
drop_cols = ["category1", "category2"]

for c in drop_cols:
    for s in suffixes:
        col = c+s
        train_df.drop(col, axis=1, inplace=True)
        test_df.drop(col, axis=1, inplace=True)

# %%
train_df.columns
# Out:
# Index(['period', 'game-ver', 'lobby-mode', 'lobby', 'mode', 'stage',
#        'A1-weapon', 'A1-rank', 'A1-level', 'A2-weapon', 'A2-rank', 'A2-level',
#        'A3-weapon', 'A3-rank', 'A3-level', 'A4-weapon', 'A4-rank', 'A4-level',
#        'B1-weapon', 'B1-rank', 'B1-level', 'B2-weapon', 'B2-rank', 'B2-level',
#        'B3-weapon', 'B3-rank', 'B3-level', 'B4-weapon', 'B4-rank', 'B4-level',
#        'y', 'subweapon-A1', 'special-A1', 'mainweapon-A1', 'reskin-A1',
#        'subweapon-A2', 'special-A2', 'mainweapon-A2', 'reskin-A2',
#        'subweapon-A3', 'special-A3', 'mainweapon-A3', 'reskin-A3',
#        'subweapon-A4', 'special-A4', 'mainweapon-A4', 'reskin-A4',
#        'subweapon-B1', 'special-B1', 'mainweapon-B1', 'reskin-B1',
#        'subweapon-B2', 'special-B2', 'mainweapon-B2', 'reskin-B2',
#        'subweapon-B3', 'special-B3', 'mainweapon-B3', 'reskin-B3',
#        'subweapon-B4', 'special-B4', 'mainweapon-B4', 'reskin-B4'],
#       dtype='object')

# %%
y = train_df["y"]
train_df.drop("y", axis=1, inplace=True)

train_df,  test_df = prepro.addTeamInfo(train_df, test_df)
#train,  test = addTeamInfo(train_df, test_df)
# Out:
# (94465, 62)
# ['presser', 'curlingbomb_pitcher', 'ultrahanko', 'bubble', 'amefurashi', 'missile', 'armor', 'robotbomb_pitcher', 'sphere', 'kyubanbomb_pitcher', 'splashbomb_pitcher', 'quickbomb_pitcher', 'nicedama', 'chakuchi', 'jetpack']
# ['splashbomb', 'curlingbomb', 'poisonmist', 'sprinkler', 'quickbomb', 'torpedo', 'kyubanbomb', 'robotbomb', 'trap', 'splashshield', 'tansanbomb', 'jumpbeacon', 'pointsensor']
# special-A
# special-B
# subweapon-A
# subweapon-B
# (94465, 118)
# complete

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (66125, 118)
# (28340, 118)

# %%
drop_cols = ["id", "lobby", "lobby-mode",  "period", "game-ver", "A1-weapon", "A2-weapon", "A3-weapon", "A4-weapon", \
              "B1-weapon", "B2-weapon", "B3-weapon", "B4-weapon"]
X, test_X = prepro.make_input(train_df, test_df, drop_cols)
# Out:
# period
# game-ver
# lobby-mode
# lobby
# mode
# stage
# A1-weapon
# A1-rank
# A1-level
# A2-weapon
# A2-rank
# A2-level
# A3-weapon
# A3-rank
# A3-level
# A4-weapon
# A4-rank
# A4-level
# B1-weapon
# B1-rank
# B1-level
# B2-weapon
# B2-rank
# B2-level
# B3-weapon
# B3-rank
# B3-level
# B4-weapon
# B4-rank
# B4-level
# subweapon-A1
# special-A1
# mainweapon-A1
# reskin-A1
# subweapon-A2
# special-A2
# mainweapon-A2
# reskin-A2
# subweapon-A3
# special-A3
# mainweapon-A3
# reskin-A3
# subweapon-A4
# special-A4
# mainweapon-A4
# reskin-A4
# subweapon-B1
# special-B1
# mainweapon-B1
# reskin-B1
# subweapon-B2
# special-B2
# mainweapon-B2
# reskin-B2
# subweapon-B3
# special-B3
# mainweapon-B3
# reskin-B3
# subweapon-B4
# special-B4
# mainweapon-B4
# reskin-B4
# presser-A
# curlingbomb_pitcher-A
# ultrahanko-A
# bubble-A
# amefurashi-A
# missile-A
# armor-A
# robotbomb_pitcher-A
# sphere-A
# kyubanbomb_pitcher-A
# splashbomb_pitcher-A
# quickbomb_pitcher-A
# nicedama-A
# chakuchi-A
# jetpack-A
# presser-B
# curlingbomb_pitcher-B
# ultrahanko-B
# bubble-B
# amefurashi-B
# missile-B
# armor-B
# robotbomb_pitcher-B
# sphere-B
# kyubanbomb_pitcher-B
# splashbomb_pitcher-B
# quickbomb_pitcher-B
# nicedama-B
# chakuchi-B
# jetpack-B
# splashbomb-A
# curlingbomb-A
# poisonmist-A
# sprinkler-A
# quickbomb-A
# torpedo-A
# kyubanbomb-A
# robotbomb-A
# trap-A
# splashshield-A
# tansanbomb-A
# jumpbeacon-A
# pointsensor-A
# splashbomb-B
# curlingbomb-B
# poisonmist-B
# sprinkler-B
# quickbomb-B
# torpedo-B
# kyubanbomb-B
# robotbomb-B
# trap-B
# splashshield-B
# tansanbomb-B
# jumpbeacon-B
# pointsensor-B

# %%
for col in X.columns:
    print(col)
# Out:
# mode
# stage
# A1-rank
# A1-level
# A2-rank
# A2-level
# A3-rank
# A3-level
# A4-rank
# A4-level
# B1-rank
# B1-level
# B2-rank
# B2-level
# B3-rank
# B3-level
# B4-rank
# B4-level
# subweapon-A1
# special-A1
# mainweapon-A1
# reskin-A1
# subweapon-A2
# special-A2
# mainweapon-A2
# reskin-A2
# subweapon-A3
# special-A3
# mainweapon-A3
# reskin-A3
# subweapon-A4
# special-A4
# mainweapon-A4
# reskin-A4
# subweapon-B1
# special-B1
# mainweapon-B1
# reskin-B1
# subweapon-B2
# special-B2
# mainweapon-B2
# reskin-B2
# subweapon-B3
# special-B3
# mainweapon-B3
# reskin-B3
# subweapon-B4
# special-B4
# mainweapon-B4
# reskin-B4
# presser-A
# curlingbomb_pitcher-A
# ultrahanko-A
# bubble-A
# amefurashi-A
# missile-A
# armor-A
# robotbomb_pitcher-A
# sphere-A
# kyubanbomb_pitcher-A
# splashbomb_pitcher-A
# quickbomb_pitcher-A
# nicedama-A
# chakuchi-A
# jetpack-A
# presser-B
# curlingbomb_pitcher-B
# ultrahanko-B
# bubble-B
# amefurashi-B
# missile-B
# armor-B
# robotbomb_pitcher-B
# sphere-B
# kyubanbomb_pitcher-B
# splashbomb_pitcher-B
# quickbomb_pitcher-B
# nicedama-B
# chakuchi-B
# jetpack-B
# splashbomb-A
# curlingbomb-A
# poisonmist-A
# sprinkler-A
# quickbomb-A
# torpedo-A
# kyubanbomb-A
# robotbomb-A
# trap-A
# splashshield-A
# tansanbomb-A
# jumpbeacon-A
# pointsensor-A
# splashbomb-B
# curlingbomb-B
# poisonmist-B
# sprinkler-B
# quickbomb-B
# torpedo-B
# kyubanbomb-B
# robotbomb-B
# trap-B
# splashshield-B
# tansanbomb-B
# jumpbeacon-B
# pointsensor-B

# %%
import random

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
from lightgbm import LGBMClassifier


random.seed(0)
# Out:
# /opt/anaconda3/envs/spla/lib/python3.6/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
# 全データを5つに分割
SIZE = X.shape[0]
K = 5

def make_kfolds(SIZE, K):
    # return list object, each element is indices of its fold
    FOLD_SIZE = int(SIZE/K)
    res = []
    indices = [i for i in range(SIZE)]
    for i in range(K-1):
        fold = random.sample(indices, FOLD_SIZE)
        indices = list(set(indices) - set(fold))
        res.append(fold)
    res.append(indices)
    return res

folds = make_kfolds(SIZE, K)
print(len(folds))
for i, fold in enumerate(folds):
    print("fold ", i+1, " size is ", len(fold))
    

    
if SIZE != len(set(sum(folds, []))):
    print("error is occuring in spliting")
else :
    print("successfully split")
# Out:
# 5
# fold  1  size is  13225
# fold  2  size is  13225
# fold  3  size is  13225
# fold  4  size is  13225
# fold  5  size is  13225
# successfully split

# %%
param = {
    "num_leaves" : 20,
    "n_estimators" : 100,
    "learning_rate" : 0.1,
    "num_iterations" : 50,
    "objective" : "binary",
    "metric" : ["binary_logloss"],
}

THRESHOLD = 0.505
models = []
cv_scores = []
temp = 0

all_indices = sum(folds, [])
for i in range(K):
    valid_indices = folds[i]
    train_indices = list(set(all_indices) - set(valid_indices))
    # print("train ", len(train_indices), " , valid ", len(valid_indices))
    train_X = X.iloc[train_indices].values
    train_y = y.iloc[train_indices].values
    valid_X = X.iloc[valid_indices].values
    valid_y = y.iloc[valid_indices].values
    
    train_data = lgb.Dataset(train_X, label=train_y)
    valid_data = lgb.Dataset(valid_X, label=valid_y)
    
    model = lgb.train(param, train_data, valid_sets=valid_data, early_stopping_rounds=2, verbose_eval=10)
    pred = model.predict(valid_X)
    pred = np.where(pred < THRESHOLD, 0, 1)
    temp += np.sum(pred)
    
    score = accuracy_score(pred, valid_y)
    
    models.append(model)
    cv_scores.append(score)
    
    
print("cv score : ", np.mean(cv_scores))    
print("cv ratio : ", temp / SIZE)
# Out:
# /opt/anaconda3/envs/spla/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 2 rounds
# [10]	valid_0's binary_logloss: 0.690169
# [20]	valid_0's binary_logloss: 0.689469
# Early stopping, best iteration is:
# [24]	valid_0's binary_logloss: 0.689021
# Training until validation scores don't improve for 2 rounds
# [10]	valid_0's binary_logloss: 0.688755
# [20]	valid_0's binary_logloss: 0.687532
# [30]	valid_0's binary_logloss: 0.686812
# Early stopping, best iteration is:
# [33]	valid_0's binary_logloss: 0.686707
# Training until validation scores don't improve for 2 rounds
# [10]	valid_0's binary_logloss: 0.689304
# [20]	valid_0's binary_logloss: 0.688655
# Early stopping, best iteration is:
# [19]	valid_0's binary_logloss: 0.688579
# Training until validation scores don't improve for 2 rounds
# [10]	valid_0's binary_logloss: 0.687998
# [20]	valid_0's binary_logloss: 0.686824
# Early stopping, best iteration is:
# [20]	valid_0's binary_logloss: 0.686824
# Training until validation scores don't improve for 2 rounds
# [10]	valid_0's binary_logloss: 0.688295
# [20]	valid_0's binary_logloss: 0.68742
# Early stopping, best iteration is:
# [18]	valid_0's binary_logloss: 0.687368
# cv score :  0.5377996219281663
# cv ratio :  0.7385557655954631

# %%
preds = []
for i in range(K):
    model = models[i]
    pred = model.predict(test_X)
    preds.append(pred)
    print(np.sum(pred) / pred.shape[0])
    
preds = np.array(preds)
preds = np.mean(preds, axis=0)
print(np.sum(preds) / preds.shape[0])


temp = pd.DataFrame({"pred":pred})
temp.hist(bins=20)
# Out:
# 0.5273720993213783
# 0.5249339843345165
# 0.5242196932146331
# 0.521763748316817
# 0.5241842634246696
# 0.5244947577224028
# array([[<AxesSubplot:title={'center':'pred'}>]], dtype=object)

# %%
preds = np.where(preds < THRESHOLD, 0, 1)
print(np.sum(preds) / preds.shape[0])

submit_df = pd.DataFrame({'y': preds})
submit_df.index.name = 'id'
submit_df.to_csv('../Submissions/submission7.csv')
# Out:
# 0.7670077628793225
