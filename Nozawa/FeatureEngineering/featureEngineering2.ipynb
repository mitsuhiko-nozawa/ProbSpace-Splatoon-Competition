# %% [markdown]
# ## 武器の外部データの結合
# 元データのweaponを主キーとして武器データをくっつける
#
# 武器が欠損している場合は全て欠損させた

# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv("../../data/Processed/train1.csv")
test_df = pd.read_csv("../../data/Raw/test_data.csv")
#buki_df = pd.read_csv("../../data/Raw/statink-weapon2.csv", usecols=["category1", "category2", "key", "subweapon", "special", "mainweapon", "reskin"])
buki_df = pd.read_csv("../../data/Processed/buki2.csv")
print(buki_df.shape)
buki_df.head(10)
# Out:
# (139, 21)
#    category1  category2                  key     subweapon special  \
# 0    shooter    shooter                52gal   pointsensor  sphere
# 1    slosher    slosher     explosher_custom   pointsensor  sphere
# 2  splatling  splatling           nautilus47   pointsensor  sphere
# 3    shooter    reelgun            l3reelgun   curlingbomb  sphere
# 4    shooter    shooter        promodeler_rg     sprinkler  sphere
# 5    charger    charger  splatcharger_becchu     sprinkler  sphere
# 6    charger    charger    splatscope_becchu     sprinkler  sphere
# 7    slosher    slosher   bucketslosher_deco     sprinkler  sphere
# 8    shooter   maneuver       kelvin525_deco  splashshield  sphere
# 9    shooter   maneuver      maneuver_becchu    kyubanbomb  sphere
#
#       mainweapon               reskin  range-main  atack-main  rapid-main  \
# 0          52gal                52gal          55          75          25
# 1      explosher     explosher_custom          77          64          20
# 2     nautilus47           nautilus47          74          36          69
# 3      l3reelgun            l3reelgun          62          25          65
# 4  promodeler_mg        promodeler_rg          35          10          90
# 5   splatcharger  splatcharger_becchu          88          50          40
# 6   splatcharger    splatscope_becchu          91          50          30
# 7  bucketslosher   bucketslosher_deco          58          85          50
# 8      kelvin525       kelvin525_deco          62          76          35
# 9       maneuver      maneuver_becchu          50          22          70
#
#    ...  fav-main  damage_min-sub  damage_max-sub  ink-sub  install_num-sub  \
# 0  ...       815             0.0             0.0       60                0
# 1  ...       500             0.0             0.0       60                0
# 2  ...       593             0.0             0.0       60                0
# 3  ...       572            20.0           150.0       70                0
# 4  ...       718            20.0            20.0       70                1
# 5  ...       439            20.0            20.0       70                1
# 6  ...       367            20.0            20.0       70                1
# 7  ...      1127            20.0            20.0       70                1
# 8  ...       730            30.0            30.0       60                1
# 9  ...      1037            30.0           180.0       70                0
#
#    good-sub  damage_min-special  damage_max-special  duration-special  \
# 0        49                55.0               180.0                 7
# 1        49                55.0               180.0                 7
# 2        49                55.0               180.0                 7
# 3       121                55.0               180.0                 7
# 4        86                55.0               180.0                 7
# 5        86                55.0               180.0                 7
# 6        86                55.0               180.0                 7
# 7        86                55.0               180.0                 7
# 8        57                55.0               180.0                 7
# 9       104                55.0               180.0                 7
#
#    good-special
# 0            78
# 1            78
# 2            78
# 3            78
# 4            78
# 5            78
# 6            78
# 7            78
# 8            78
# 9            78
#
# [10 rows x 21 columns]

# %%
print(train_df.shape)
train_df.head(10)

# %%
def merge_buki(df, buki_df):
    res = pd.merge(df, buki_df, left_on="A1-weapon", right_on="key", how="outer", suffixes=["", ""]).drop(columns='key')
    res = pd.merge(res, buki_df, left_on="A2-weapon", right_on="key", how="outer", suffixes=["", "-A2"]).drop(columns='key')
    res = pd.merge(res, buki_df, left_on="A3-weapon", right_on="key", how="outer", suffixes=["", "-A3"]).drop(columns='key')
    res = pd.merge(res, buki_df, left_on="A4-weapon", right_on="key", how="outer", suffixes=["", "-A4"]).drop(columns='key')
    res = pd.merge(res, buki_df, left_on="B1-weapon", right_on="key", how="outer", suffixes=["", "-B1"]).drop(columns='key')
    res = pd.merge(res, buki_df, left_on="B2-weapon", right_on="key", how="outer", suffixes=["", "-B2"]).drop(columns='key')
    res = pd.merge(res, buki_df, left_on="B3-weapon", right_on="key", how="outer", suffixes=["", "-B3"]).drop(columns='key')
    res = pd.merge(res, buki_df, left_on="B4-weapon", right_on="key", how="outer", suffixes=["-A1", "-B4"]).drop(columns='key')
    return res

# %%
train_df = merge_buki(train_df, buki_df)
test_df = merge_buki(test_df, buki_df)

# %%
print(train_df.shape)
print(test_df.shape)

# %%
train_df.sort_values('id', inplace=True)
test_df.sort_values('id', inplace=True)

# %%
train_df.to_csv("../../data/Processed/train2.csv", index=False)
test_df.to_csv("../../data/Processed/test2.csv", index=False)

# %%
temp = pd.read_csv("../../data/Processed/train2.csv", index_col="id")
temp.head()

# %%
for col in train_df.columns:
    print(col)
